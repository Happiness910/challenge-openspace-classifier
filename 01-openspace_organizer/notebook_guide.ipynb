# %% [markdown]
# # Open Space Organizer
#
# We want to create a program that assigns 24 people to 6 tables in an openspace. Before getting started, take inventory what do we need:
#
# - People
# - Seats & Tables
# - An OpenSpace
#
# It's a good practice to start simple while you grasp the logic of the program you are trying to build and test often. For us this can translate to,
#
# - People -> List of Names (later we can figure out how to use a file)
# - Seats & Tables -> Class
# - An OpenSpace -> Class
#
# Below I've created a list of your new colleagues for reference!

# %%
new_collegues = ["Anna", "Dan", "Gaetan", "Guillermo", "Gunay", 
                         "Hiba", "Hussein", "Ibrahim", "Ibtihel", "Imad", "Iness", 
                         "Irene","Jeong", "Mahalakshmi", "Max", "Neha", "Siegried", 
                         "Sitara", "Sooyoung", "Stephane", "Thi", "Uzair", "Victor", "Vanessa"]

# %% [markdown]
# ## Step 1: Build a Seat
#
# Create a class called `Seat` with two attributes:
#
# - `free` which is a boolean.
# - `occupant` which is a string.
#
# and 2 methods (functions):
#
# - `set_occupant(name)` which allows the program to assign someone a seat if it's free
# - `remove_occupant()` which  remove someone from a seat and return the name of the person occupying the seat before

# %%
# Your code here
class Seat:
    """
    1) setting the intrinsical parameters to the object/class Seat and precise their type
    2)
    """
    def __init__(self, free: bool, occupant: str): 
        """ 
        Ainsi la classe Seat est vue comme un plan :
        Chaise : free=True   occupant = "..."
        """
        #self obligatoire pour les méthodes d'instance
        #! aux espaces entre "X: bool"
        self.free = free
        self.occupant = occupant

    def set_occupant(self, name): #self = la chaise elle-même, si le self n'est pas précisé, la méthode ne sait pas sur quelle chaise travailler
        #je ne dois pas créer de nouvelles données à chaque fois dans une fonction, surtout si c'est déjà mis en init. Les données vivent déjà dans l'objet/classe
        #remettre des self.free revient a créer à nouveau un free. Je dois le lire ou le modifier, pas le recréer.
        """
        la méthode ne sait pas quelle chaisse elle manipule
        """
        #FAUX de mettre self.name = name car la chaise ne possède pas le nom, il sera reçu et servira a remplir l'occupant
        #name est une donnée reçu, pas un truc propre à la chaise
        #la chaise ne possède pas name naturellement

        if free is True: #peut-être demandé à la personne de l'ajouter
            occupant = name
            return f"{name} can seat here" 
            free is False #il faut rendre free FAUX !!!
        #en partant du principe que la fonction set_occupant recevra un nom déjà choisi et je l'assigne
        #responsabilité externe
        else:
            return f"someone is already sitting here"
            #il faut refuser mais comment ?

    
    #def remove_occupant():
        """
        remove someone's name sitting in the seat
        return someone's name 2 that was seat before someone's name 1
        """

#ne pas oublier d'ajouter l'explication du raisonnement

# %% [markdown]
# `set_occupant(name)` allows the program to assign someone a seat if it's free
#
# => condition : "if the seat is free, assign someone to the seat"
#
# If the seat is free, free is True, name put in occupant\
# If the seat is occupied, free is False, no name added in occupant
#
# Ok but after ?\
# If seat is free, after, we have to mentioned that it's occupied
# If seat is occupied, we have to block the seat

# %%
class Seat:
    def __init__(self, free: bool, occupant: str): 
        self.free = free
        self.occupant = occupant

    def set_occupant(self, name):
        if self.free == True: #free doit être un attribut de l'objet : self.free et non free dans la condition !
            self.occupant = name
            #il faut ensuite rendre la place non libre!!
            self.free = False
            return f"{name} can seat here"
        else :
            return f"someone is already sitting here"
            #pass
            #2 possibilités : est ce que je veux ignorer le cas (pass) ou informer ce qui se passe (return)
             
    def remove_occupant(self, name, previous_name): #part du principe que la personne précédemment assise à un nom fixe et donnée
        occupant = "" #removing the name
        #print("occupant", occupant) verification
        return f"{previous_name} sat here before {name}, who's removed from the seat"
    #il faut mettre un self pour chaque methode créé
    #pour appeler les nouveaux paramètres, il faut les mettres dans la paranthèses
    #si ces nouveaux paramètres sont propre à l'objet, il faut créé des self.X = X, sauf si deja mis dans le init, auquel cas il ne faut pas répéter (si cétait dans d'autres méthodes que init la 1ere fois qu'on appelle ca passe ?)
    #si ce sont des paramètres fixe transmis de l'exterieur : pas de self (ex: name, previous name)

# %%
# Test your code (assign yourself you a Seat)
test = Seat(False, "")
test.set_occupant("Edgar") #ne jamais appelé une classe directement sur une de ces methodes par ex: seat.set_occupant (...) FAUX FAUX FAUX
#on appelle toujours une methode sur une instance (cad un objet réel qu'on aura nommé et donné sa fiche au préalable)
# Out:
# 'someone is already sitting here'

# %% [markdown]
#  `remove_occupant()` remove someone from a seat and return the name of the person occupying the seat before

# %%
test2 = Seat(True,"")
test2.remove_occupant("Edgar","Franc")
        #comment appele les paramètres previous_name et name et occupant et est ce qu'il faut un self
# Out:
# "Franc sat here before Edgar, who's removed from the seat"

# %% [markdown]
# What is the input and the output of your Seat class? Does it make sense?
#
# ## Step 2: Build a Table
#
# Create a class `Table` with ? attributes:
#
# - `capacity` which is an integer
# - `seats` which is a list of `Seat` objects (size = `capacity`)
#
# and 3 methods (functions):
# - `has_free_spot()` that returns a boolean (True if a spot is available)
# - `assign_seat(name)` that places someone at the table
# - `left_capacity()` that returns an integer
#
# Question: Which attributes make sense to give? For now let's say we want to build 6 tables with 4 seats.

# %%
# Your code here
class Table:
    def __init__(self, capacity: int, seats: list): #seats is a list of Seat objects and size = capacity, je garde l'info de côté
        self.capacity = capacity
        self.seats = seats
    def has_free_spot(self,seats, Seat): #je pars du principe que la capacité est fixé, que le max est 4 places
        for Seat in self.seats:
            if Seat.free == True:
                return True
            else:
                return f"False"
    
    def assign_seat(self, name):
        capacity = 0
        for Seat in self.seats:
            Seat.occupant = name
            capacity +=1
            return f"{name} is placed in that table at {seat}"
    
    def left_capacity(self, capacity):
        left_c = 4 - capacity
        return f"The capacity left : {left_c}" #ajoute un if capacity = 4, return no more place et si < 4 alors il reste X place

# %%
# Test your code (assign the colleagues at your table to a Table)
seats = [Seat(False,""),Seat(True,""),Seat(False,"")]
seat = seats[1]
test3 = Table(4,seats1)
test3.has_free_spot(seats1,seat)
# Out:
# 'False'

# %%
test4 = Table(4, seats1)
test4.assign_seat('Farah')

test5 = Table(4, seats1)
test5.left_capacity(4)
# Out:
# 'The capacity left : 0'

# %%
#régler le problème avec la classe Seat et voir comment améliorer à ce niveau là pcq j'ai l'impression d'être à chaque fois parti d'une position specifique de la liste des seats, revenir dessus après avoir vu le step 3

# %% [markdown]
# Does the output of you test make sense? Check that each method returns the correct value.

# %% [markdown]
# ## Step 3: Build an OpenSpace
#
# Create a class `Openspace` that contains these attributes:
#
# - `tables` which is a list of `Table`.
# - `number_of_tables` which is an integer.
#
# And some methods:
#
# - `organize(names)` that will:
#   - **randomly** assign people to `Seat` objects in the different `Table` objects. (hint: explore the `random` library )
# - `display()` display the different tables and there occupants in a nice and readable way
# - `store(filename)` store the repartition in an file

# %%
# Your code here
import random 
class Openspace:

    def __init__(self, tables: list, number_of_tables: int):
        self.tables = tables
        self.number_of_tables = number_of_tables

    def organize(self, names, table, tables, seat, seats, occupant):
        for Table in self.tables: #and capacity < 4
            for Seat in self.seats and seat.free == True :
                occupant = str(random.choice(names))
                return f"it has randomly choice {occupant} to sit in {seat} at {table}"
    
    def display(self, table, tables, names):
        for Table in self.tables:
            return f"{names} are at table {table} n\""
    
    #def store(filename):
    # a faire !!

# %%
# Test your code (assign everyone in the class to a table)

# %% [markdown]
# Hurray! You have the algorithm logic working. Next steps we transform this into some scripts! **Big note:** Once you move to the scrips you may need to adapt your logic.
